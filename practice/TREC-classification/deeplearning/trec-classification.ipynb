# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Download data

# %%
# !wget https://cogcomp.seas.upenn.edu/Data/QA/QC/TREC_10.label -O test.label
# !wget https://cogcomp.seas.upenn.edu/Data/QA/QC/train_5500.label -O train.label
# Out:
# --2022-10-20 14:58:05--  https://cogcomp.seas.upenn.edu/Data/QA/QC/TREC_10.label
# Resolving cogcomp.seas.upenn.edu (cogcomp.seas.upenn.edu)... 158.130.57.77
# Connecting to cogcomp.seas.upenn.edu (cogcomp.seas.upenn.edu)|158.130.57.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23354 (23K)
# Saving to: ‘test.label’
#
# test.label          100%[===================>]  22.81K  --.-KB/s    in 0.07s
#
# 2022-10-20 14:58:05 (345 KB/s) - ‘test.label’ saved [23354/23354]
#
# --2022-10-20 14:58:06--  https://cogcomp.seas.upenn.edu/Data/QA/QC/train_5500.label
# Resolving cogcomp.seas.upenn.edu (cogcomp.seas.upenn.edu)... 158.130.57.77
# Connecting to cogcomp.seas.upenn.edu (cogcomp.seas.upenn.edu)|158.130.57.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 335858 (328K)
# Saving to: ‘train.label’
#
# train.label         100%[===================>] 327.99K   982KB/s    in 0.3s
#
# 2022-10-20 14:58:08 (982 KB/s) - ‘train.label’ saved [335858/335858]

# %%
# !head -n 10 test.label
# Out:
# NUM:dist How far is it from Denver to Aspen ?
# LOC:city What county is Modesto , California in ?
# HUM:desc Who was Galileo ?
# DESC:def What is an atom ?
# NUM:date When did Hawaii become a state ?
# NUM:dist How tall is the Sears Building ?
# HUM:gr George Bush purchased a small interest in which baseball team ?
# ENTY:plant What is Australia 's national flower ?
# DESC:reason Why does the moon turn orange ?
# DESC:def What is autism ?

# %%
# !head -n 10 train.label
# Out:
# DESC:manner How did serfdom develop in and then leave Russia ?
# ENTY:cremat What films featured the character Popeye Doyle ?
# DESC:manner How can I find a list of celebrities ' real names ?
# ENTY:animal What fowl grabs the spotlight after the Chinese Year of the Monkey ?
# ABBR:exp What is the full form of .com ?
# HUM:ind What contemptible scoundrel stole the cork from my lunch ?
# HUM:gr What team did baseball 's St. Louis Browns become ?
# HUM:title What is the oldest profession ?
# DESC:def What are liver enzymes ?
# HUM:ind Name the scar-faced bounty hunter of The Old West .

# %% [markdown]
# # Preprocessing
#
# ## Separate the question and the label

# %%
import codecs

# %%
def generate_examples(filepath):
    examples = []

    with codecs.open(filepath, "rb+") as f:
        for id_, row in enumerate(f):
            # ByteError in a sample
            label, _, text = row.replace(b"\xf0", b" ").strip().decode().partition(" ")

            coarse_label, _, fine_label = label.partition(":")

            examples.append((id_, {
                "label-coarse" : coarse_label,
                "label-fine" : fine_label,
                "text" : text,
            }))
    
    return examples

# %%
train = generate_examples("train.label")
test = generate_examples("test.label")

# %%
print(len(train))
print(train[0])
# Out:
# 5452
# (0, {'label-coarse': 'DESC', 'label-fine': 'manner', 'text': 'How did serfdom develop in and then leave Russia ?'})

# %%
print(len(test))
print(test[0])
# Out:
# 500
# (0, {'label-coarse': 'NUM', 'label-fine': 'dist', 'text': 'How far is it from Denver to Aspen ?'})

# %% [markdown]
# ## Separate sentence and label

# %%
labels = [x["label-coarse"] for _, x in train]

# %%
len(labels)
# Out:
# 5452

# %%
set_labels = list(set(labels))

# %%
set_labels
# Out:
# ['HUM', 'LOC', 'NUM', 'ENTY', 'ABBR', 'DESC']

# %%
word2idx = {set_labels[i] : i for i in range(len(set_labels))}
idx2word = {i : set_labels[i] for i in range(len(set_labels))}

# %%
word2idx
# Out:
# {'HUM': 0, 'LOC': 1, 'NUM': 2, 'ENTY': 3, 'ABBR': 4, 'DESC': 5}

# %%
idx2word
# Out:
# {0: 'HUM', 1: 'LOC', 2: 'NUM', 3: 'ENTY', 4: 'ABBR', 5: 'DESC'}

# %% [markdown]
# ## Data processing pipeline

# %%
train_data = [x["text"] for _, x in train]
train_labels = [word2idx[x["label-coarse"]] for _, x in train]

# %%
print(list(zip(train_data, train_labels))[0:10])
# Out:
# [('How did serfdom develop in and then leave Russia ?', 5), ('What films featured the character Popeye Doyle ?', 3), ("How can I find a list of celebrities ' real names ?", 5), ('What fowl grabs the spotlight after the Chinese Year of the Monkey ?', 3), ('What is the full form of .com ?', 4), ('What contemptible scoundrel stole the cork from my lunch ?', 0), ("What team did baseball 's St. Louis Browns become ?", 0), ('What is the oldest profession ?', 0), ('What are liver enzymes ?', 5), ('Name the scar-faced bounty hunter of The Old West .', 0)]

# %%
test_data = [x["text"] for _, x in test]
test_labels = [word2idx[x["label-coarse"]] for _, x in test]

# %%
print(list(zip(test_data, test_labels))[0:10])
# Out:
# [('How far is it from Denver to Aspen ?', 2), ('What county is Modesto , California in ?', 1), ('Who was Galileo ?', 0), ('What is an atom ?', 5), ('When did Hawaii become a state ?', 2), ('How tall is the Sears Building ?', 2), ('George Bush purchased a small interest in which baseball team ?', 0), ("What is Australia 's national flower ?", 3), ('Why does the moon turn orange ?', 5), ('What is autism ?', 5)]

# %% [markdown]
# Create a dataset iterators

# %%
import torch
from torch.utils.data import Dataset
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator
from sklearn.model_selection import train_test_split

# %%
text_train, text_val, label_train, label_val = train_test_split(
    train_data, train_labels,
    test_size = .2,
    random_state = 42,
    stratify = train_labels
)

# %%
len(text_train), len(label_train)
# Out:
# (4361, 4361)

# %%
len(text_val), len(label_val)
# Out:
# (1091, 1091)

# %%
class TRECDataset(Dataset):
    def __init__(self, text, label):
        self.text = text
        self.label = label
        
        self.length = len(self.text)
    
    def __getitem__(self, idx):
        return self.text[idx], self.label[idx]
    
    def __len__(self):
        return self.length

# %%
train_dataset = TRECDataset(text_train, label_train)
val_dataset = TRECDataset(text_val, label_val)

# %%
next(iter(train_dataset))
# Out:
# ('What is the Milky Way ?', 5)

# %%
next(iter(val_dataset))
# Out:
# ("What is the origin of the ethnic category `` caucasian '' ?", 5)

# %% [markdown]
# Create a tokenizer, to build a vocabulary

# %%
tokenizer = get_tokenizer("basic_english")

# %%
def yield_tokens(data_iter):
    for text, _ in data_iter:
        yield tokenizer(text)

# %%
train_iter = iter(train_dataset)

# %%
next(yield_tokens(train_iter))
# Out:
# ['what', 'is', 'the', 'milky', 'way', '?']

# %%
vocabulary = build_vocab_from_iterator(yield_tokens(train_iter), specials = ["<unk>"])
vocabulary.set_default_index(vocabulary["<unk>"])

# %%
len(vocabulary)
# Out:
# 7509

# %%
vocabulary(tokenizer("who want to be a millionare ?"))
# Out:
# [12, 1799, 14, 49, 8, 0, 1]

# %% [markdown]
# ## Generate data batch and iterator

# %%
from torch.utils.data import DataLoader

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def collate_batch(batch):
    text_list, label_list, offsets = [], [], [0]
    
    for (text_, label_) in batch:
        text_tensor = torch.tensor(vocabulary(tokenizer(text_)), dtype = torch.int64)
        text_list.append(text_tensor)
        offsets.append(text_tensor.size(0))
        
        
        label_list.append(label_)
    
    label_list = torch.tensor(label_list, dtype = torch.int64)
    offsets = torch.tensor(offsets[:-1]).cumsum(dim = 0)
    text_list = torch.cat(text_list)
    
    return text_list.to(device), label_list.to(device), offsets.to(device)

# %% [markdown]
# # Model

# %% [markdown]
# ## Architecture

# %%
class TREC_classification_Model(torch.nn.Module):
    def __init__(self, vocab_size, embedding_dim, num_classes):
        super(TREC_classification_Model, self).__init__()
        
        self.embedding = torch.nn.EmbeddingBag(
            num_embeddings = vocab_size,
            embedding_dim = embedding_dim,
        )
        
        self.fc1 = torch.nn.Linear(
            in_features = embedding_dim, 
            out_features = 128
        )
        
        self.dropout1 = torch.nn.Dropout(.6)
        
        self.fc2 = torch.nn.Linear(
            in_features = 128,
            out_features = num_classes
        )
        
        self.sigmoid = torch.nn.Sigmoid()
        
        self.init_weights()
    
    def init_weights(self):
        range_ = .5
        
        self.embedding.weight.data.uniform_(-range_, range_)
        
        self.fc1.weight.data.uniform_(-range_, range_)
        self.fc1.bias.data.zero_()        
        
        self.fc2.weight.data.uniform_(-range_, range_)
        self.fc2.bias.data.zero_()   
    
    def forward(self, text, offsets):
        embedded = self.embedding(text, offsets)
        fc1 = self.fc1(embedded)
        dropout1 = self.dropout1(fc1)
        fc2 = self.fc2(dropout1)
        sigmoid = self.sigmoid(fc2)
        return sigmoid

# %% [markdown]
# Hyperparameters

# %%
num_class = len(set_labels)
vocab_size = len(vocabulary)
embedding_size = 64

# %%
model = TREC_classification_Model(vocab_size, embedding_size, num_class).to(device)

# %% [markdown]
# ## Training & evaluating function

# %%
import time

# %%
def train(dataloader):
    model.train()
    
    total_accuracy, total_count = 0, 0
    log_interval = 20
    
    start_time = time.time()
    
    for idx, (text, label, offsets) in enumerate(dataloader):
        optimizer.zero_grad()
        
        predicted_label = model(text, offsets)
        
        # Loss and backpropagation
        loss = loss_fn(predicted_label, label)
        loss.backward()
        
        # Clip grad
        torch.nn.utils.clip_grad_norm_(model.parameters(), .1)
        optimizer.step()
        
        total_accuracy += (predicted_label.argmax(1) == label).sum().item()
        
        total_count += label.size(0)
        
        if idx % log_interval == 0 and idx > 0:
            elapsed = time.time() - start_time
            
            accuracy = total_accuracy / total_count
            
            print(f"Epoch: {epoch + 1} | Batch: {idx}/{len(dataloader)} | Loss: {loss:.6f} | Accuracy: {accuracy:.6f}")
            
            total_accuracy, total_count = 0, 0
            
            start_time = time.time()

# %%
def evaluate(dataloader):
    model.eval()
    
    total_loss, total_acc, total_count = 0, 0, 0
    
    
    with torch.no_grad():
        for idx, (text, label, offsets) in enumerate(dataloader):
            predicted_label = model(text, offsets)
            
            loss = loss_fn(predicted_label, label)
            
            total_loss += loss
            total_acc += (predicted_label.argmax(1) == label).sum().item()
            total_count += label.size(0)
    
    val_accuracy = total_acc / total_count
    val_loss = total_loss / total_count
    
    return val_accuracy, val_loss

# %%
# EarlyStopping
class EarlyStopping:
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt'):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path

    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %% [markdown]
# Training

# %%
epochs = 100
learning_rate = .001
batch_size = 64
patience = 10

# %%
# Loss function
loss_fn = torch.nn.CrossEntropyLoss()

# Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# Scheduler
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma = .1)

# Early Stopping
early_stopping = EarlyStopping(patience = patience, verbose = True)

# %%
train_dataloader = DataLoader(train_dataset, batch_size = batch_size, shuffle = True, collate_fn = collate_batch)
val_dataloader = DataLoader(val_dataset, batch_size = batch_size, shuffle = True, collate_fn = collate_batch)

# %%
current_accuracy = 0.0
loss_log, accuracy_log = [], []

for epoch in range(epochs):
    epoch_start_time = time.time()
    
    train(train_dataloader)
    
    val_accuracy, val_loss = evaluate(val_dataloader)
    
    loss_log.append(val_loss)
    accuracy_log.append(val_accuracy)
    
    print("-" * 50)
    print(f"End of epoch {epoch + 1} | time: {time.time() - epoch_start_time} | val_loss: {val_loss:.6f} | val_acc: {val_accuracy:.6f}")
    print("-" * 50)
    
    early_stopping(val_loss, model)
    
    if early_stopping.early_stop:
        print("Early Stopping!")
        break
# Out:
# Epoch: 1 | Batch: 20/69 | Loss: 1.756374 | Accuracy: 0.182292
# Epoch: 1 | Batch: 40/69 | Loss: 1.675239 | Accuracy: 0.273438
# Epoch: 1 | Batch: 60/69 | Loss: 1.647739 | Accuracy: 0.343750
# --------------------------------------------------
# End of epoch 1 | time: 0.26906919479370117 | val_loss: 0.026629 | val_acc: 0.439047
# --------------------------------------------------
# Validation loss decreased (inf --> 0.026629).  Saving model ...
# Epoch: 2 | Batch: 20/69 | Loss: 1.596273 | Accuracy: 0.430060
# Epoch: 2 | Batch: 40/69 | Loss: 1.553454 | Accuracy: 0.442188
# Epoch: 2 | Batch: 60/69 | Loss: 1.519532 | Accuracy: 0.478906
# --------------------------------------------------
# End of epoch 2 | time: 0.2636744976043701 | val_loss: 0.025008 | val_acc: 0.544455
# --------------------------------------------------
# Validation loss decreased (0.026629 --> 0.025008).  Saving model ...
# Epoch: 3 | Batch: 20/69 | Loss: 1.498895 | Accuracy: 0.552083
# Epoch: 3 | Batch: 40/69 | Loss: 1.364050 | Accuracy: 0.568750
# Epoch: 3 | Batch: 60/69 | Loss: 1.458248 | Accuracy: 0.582812
# --------------------------------------------------
# End of epoch 3 | time: 0.25916194915771484 | val_loss: 0.023991 | val_acc: 0.620532
# --------------------------------------------------
# Validation loss decreased (0.025008 --> 0.023991).  Saving model ...
# Epoch: 4 | Batch: 20/69 | Loss: 1.488658 | Accuracy: 0.644345
# Epoch: 4 | Batch: 40/69 | Loss: 1.436927 | Accuracy: 0.666406
# Epoch: 4 | Batch: 60/69 | Loss: 1.385211 | Accuracy: 0.682031
# --------------------------------------------------
# End of epoch 4 | time: 0.2606394290924072 | val_loss: 0.023407 | val_acc: 0.672777
# --------------------------------------------------
# Validation loss decreased (0.023991 --> 0.023407).  Saving model ...
# Epoch: 5 | Batch: 20/69 | Loss: 1.349279 | Accuracy: 0.723958
# Epoch: 5 | Batch: 40/69 | Loss: 1.306346 | Accuracy: 0.722656
# Epoch: 5 | Batch: 60/69 | Loss: 1.318900 | Accuracy: 0.726562
# --------------------------------------------------
# End of epoch 5 | time: 0.2650773525238037 | val_loss: 0.022485 | val_acc: 0.701192
# --------------------------------------------------
# Validation loss decreased (0.023407 --> 0.022485).  Saving model ...
# Epoch: 6 | Batch: 20/69 | Loss: 1.267502 | Accuracy: 0.785714
# Epoch: 6 | Batch: 40/69 | Loss: 1.284682 | Accuracy: 0.794531
# Epoch: 6 | Batch: 60/69 | Loss: 1.339517 | Accuracy: 0.800781
# --------------------------------------------------
# End of epoch 6 | time: 0.2603473663330078 | val_loss: 0.022147 | val_acc: 0.724106
# --------------------------------------------------
# Validation loss decreased (0.022485 --> 0.022147).  Saving model ...
# Epoch: 7 | Batch: 20/69 | Loss: 1.261515 | Accuracy: 0.825149
# Epoch: 7 | Batch: 40/69 | Loss: 1.196162 | Accuracy: 0.847656
# Epoch: 7 | Batch: 60/69 | Loss: 1.209695 | Accuracy: 0.822656
# --------------------------------------------------
# End of epoch 7 | time: 0.25536251068115234 | val_loss: 0.021863 | val_acc: 0.746104
# --------------------------------------------------
# Validation loss decreased (0.022147 --> 0.021863).  Saving model ...
# Epoch: 8 | Batch: 20/69 | Loss: 1.237055 | Accuracy: 0.866815
# Epoch: 8 | Batch: 40/69 | Loss: 1.208773 | Accuracy: 0.878906
# Epoch: 8 | Batch: 60/69 | Loss: 1.197663 | Accuracy: 0.862500
# --------------------------------------------------
# End of epoch 8 | time: 0.2620570659637451 | val_loss: 0.021962 | val_acc: 0.758937
# --------------------------------------------------
# EarlyStopping counter: 1 out of 10
# Epoch: 9 | Batch: 20/69 | Loss: 1.156312 | Accuracy: 0.887649
# Epoch: 9 | Batch: 40/69 | Loss: 1.160469 | Accuracy: 0.906250
# Epoch: 9 | Batch: 60/69 | Loss: 1.226813 | Accuracy: 0.905469
# --------------------------------------------------
# End of epoch 9 | time: 0.25855350494384766 | val_loss: 0.021259 | val_acc: 0.768103
# --------------------------------------------------
# Validation loss decreased (0.021863 --> 0.021259).  Saving model ...
# Epoch: 10 | Batch: 20/69 | Loss: 1.160082 | Accuracy: 0.916667
# Epoch: 10 | Batch: 40/69 | Loss: 1.167138 | Accuracy: 0.920312
# Epoch: 10 | Batch: 60/69 | Loss: 1.147858 | Accuracy: 0.924219
# --------------------------------------------------
# End of epoch 10 | time: 0.26272010803222656 | val_loss: 0.021412 | val_acc: 0.776352
# --------------------------------------------------
# EarlyStopping counter: 1 out of 10
# Epoch: 11 | Batch: 20/69 | Loss: 1.145100 | Accuracy: 0.931548
# Epoch: 11 | Batch: 40/69 | Loss: 1.139831 | Accuracy: 0.946094
# Epoch: 11 | Batch: 60/69 | Loss: 1.114822 | Accuracy: 0.935156
# --------------------------------------------------
# End of epoch 11 | time: 0.262775182723999 | val_loss: 0.021179 | val_acc: 0.785518
# --------------------------------------------------
# Validation loss decreased (0.021259 --> 0.021179).  Saving model ...
# Epoch: 12 | Batch: 20/69 | Loss: 1.135943 | Accuracy: 0.954613
# Epoch: 12 | Batch: 40/69 | Loss: 1.122147 | Accuracy: 0.947656
# Epoch: 12 | Batch: 60/69 | Loss: 1.106443 | Accuracy: 0.944531
# --------------------------------------------------
# End of epoch 12 | time: 0.26039767265319824 | val_loss: 0.021379 | val_acc: 0.788268
# --------------------------------------------------
# EarlyStopping counter: 1 out of 10
# Epoch: 13 | Batch: 20/69 | Loss: 1.104004 | Accuracy: 0.961310
# Epoch: 13 | Batch: 40/69 | Loss: 1.091028 | Accuracy: 0.956250
# Epoch: 13 | Batch: 60/69 | Loss: 1.072770 | Accuracy: 0.960938
# --------------------------------------------------
# End of epoch 13 | time: 0.2622499465942383 | val_loss: 0.020908 | val_acc: 0.796517
# --------------------------------------------------
# Validation loss decreased (0.021179 --> 0.020908).  Saving model ...
# Epoch: 14 | Batch: 20/69 | Loss: 1.099700 | Accuracy: 0.962798
# Epoch: 14 | Batch: 40/69 | Loss: 1.099744 | Accuracy: 0.965625
# Epoch: 14 | Batch: 60/69 | Loss: 1.102824 | Accuracy: 0.965625
# --------------------------------------------------
# End of epoch 14 | time: 0.2577090263366699 | val_loss: 0.021026 | val_acc: 0.791934
# --------------------------------------------------
# EarlyStopping counter: 1 out of 10
# Epoch: 15 | Batch: 20/69 | Loss: 1.086732 | Accuracy: 0.970982
# Epoch: 15 | Batch: 40/69 | Loss: 1.110937 | Accuracy: 0.964063
# Epoch: 15 | Batch: 60/69 | Loss: 1.112180 | Accuracy: 0.967187
# --------------------------------------------------
# End of epoch 15 | time: 0.2582278251647949 | val_loss: 0.020936 | val_acc: 0.797434
# --------------------------------------------------
# EarlyStopping counter: 2 out of 10
# Epoch: 16 | Batch: 20/69 | Loss: 1.081113 | Accuracy: 0.971726
# Epoch: 16 | Batch: 40/69 | Loss: 1.098716 | Accuracy: 0.967969
# Epoch: 16 | Batch: 60/69 | Loss: 1.090673 | Accuracy: 0.973437
# --------------------------------------------------
# End of epoch 16 | time: 0.2641110420227051 | val_loss: 0.020919 | val_acc: 0.795600
# --------------------------------------------------
# EarlyStopping counter: 3 out of 10
# Epoch: 17 | Batch: 20/69 | Loss: 1.078749 | Accuracy: 0.976190
# Epoch: 17 | Batch: 40/69 | Loss: 1.079118 | Accuracy: 0.972656
# Epoch: 17 | Batch: 60/69 | Loss: 1.072223 | Accuracy: 0.968750
# --------------------------------------------------
# End of epoch 17 | time: 0.2658708095550537 | val_loss: 0.020887 | val_acc: 0.793767
# --------------------------------------------------
# Validation loss decreased (0.020908 --> 0.020887).  Saving model ...
# Epoch: 18 | Batch: 20/69 | Loss: 1.072963 | Accuracy: 0.970982
# Epoch: 18 | Batch: 40/69 | Loss: 1.071592 | Accuracy: 0.977344
# Epoch: 18 | Batch: 60/69 | Loss: 1.068816 | Accuracy: 0.975000
# --------------------------------------------------
# End of epoch 18 | time: 0.30923891067504883 | val_loss: 0.021010 | val_acc: 0.794684
# --------------------------------------------------
# EarlyStopping counter: 1 out of 10
# Epoch: 19 | Batch: 20/69 | Loss: 1.060541 | Accuracy: 0.983631
# Epoch: 19 | Batch: 40/69 | Loss: 1.080267 | Accuracy: 0.975781
# Epoch: 19 | Batch: 60/69 | Loss: 1.068395 | Accuracy: 0.972656
# --------------------------------------------------
# End of epoch 19 | time: 0.2746446132659912 | val_loss: 0.021046 | val_acc: 0.795600
# --------------------------------------------------
# EarlyStopping counter: 2 out of 10
# Epoch: 20 | Batch: 20/69 | Loss: 1.086571 | Accuracy: 0.974702
# Epoch: 20 | Batch: 40/69 | Loss: 1.066630 | Accuracy: 0.978125
# Epoch: 20 | Batch: 60/69 | Loss: 1.076543 | Accuracy: 0.974219
# --------------------------------------------------
# End of epoch 20 | time: 0.2620556354522705 | val_loss: 0.021229 | val_acc: 0.800183
# --------------------------------------------------
# EarlyStopping counter: 3 out of 10
# Epoch: 21 | Batch: 20/69 | Loss: 1.085028 | Accuracy: 0.977679
# Epoch: 21 | Batch: 40/69 | Loss: 1.062620 | Accuracy: 0.980469
# Epoch: 21 | Batch: 60/69 | Loss: 1.060873 | Accuracy: 0.983594
# --------------------------------------------------
# End of epoch 21 | time: 0.2566952705383301 | val_loss: 0.021404 | val_acc: 0.793767
# --------------------------------------------------
# EarlyStopping counter: 4 out of 10
# Epoch: 22 | Batch: 20/69 | Loss: 1.073902 | Accuracy: 0.982887
# Epoch: 22 | Batch: 40/69 | Loss: 1.054417 | Accuracy: 0.985938
# Epoch: 22 | Batch: 60/69 | Loss: 1.055681 | Accuracy: 0.978125
# --------------------------------------------------
# End of epoch 22 | time: 0.2611382007598877 | val_loss: 0.020937 | val_acc: 0.799267
# --------------------------------------------------
# EarlyStopping counter: 5 out of 10
# Epoch: 23 | Batch: 20/69 | Loss: 1.058434 | Accuracy: 0.982887
# Epoch: 23 | Batch: 40/69 | Loss: 1.063226 | Accuracy: 0.984375
# Epoch: 23 | Batch: 60/69 | Loss: 1.049971 | Accuracy: 0.982812
# --------------------------------------------------
# End of epoch 23 | time: 0.2622687816619873 | val_loss: 0.021211 | val_acc: 0.798350
# --------------------------------------------------
# EarlyStopping counter: 6 out of 10
# Epoch: 24 | Batch: 20/69 | Loss: 1.064945 | Accuracy: 0.979911
# Epoch: 24 | Batch: 40/69 | Loss: 1.053330 | Accuracy: 0.983594
# Epoch: 24 | Batch: 60/69 | Loss: 1.074297 | Accuracy: 0.982031
# --------------------------------------------------
# End of epoch 24 | time: 0.26016974449157715 | val_loss: 0.021132 | val_acc: 0.793767
# --------------------------------------------------
# EarlyStopping counter: 7 out of 10
# Epoch: 25 | Batch: 20/69 | Loss: 1.074911 | Accuracy: 0.982887
# Epoch: 25 | Batch: 40/69 | Loss: 1.065813 | Accuracy: 0.989062
# Epoch: 25 | Batch: 60/69 | Loss: 1.067235 | Accuracy: 0.983594
# --------------------------------------------------
# End of epoch 25 | time: 0.2609741687774658 | val_loss: 0.021245 | val_acc: 0.791934
# --------------------------------------------------
# EarlyStopping counter: 8 out of 10
# Epoch: 26 | Batch: 20/69 | Loss: 1.049583 | Accuracy: 0.981399
# Epoch: 26 | Batch: 40/69 | Loss: 1.056891 | Accuracy: 0.985938
# Epoch: 26 | Batch: 60/69 | Loss: 1.062543 | Accuracy: 0.989844
# --------------------------------------------------
# End of epoch 26 | time: 0.2611258029937744 | val_loss: 0.020971 | val_acc: 0.797434
# --------------------------------------------------
# EarlyStopping counter: 9 out of 10
# Epoch: 27 | Batch: 20/69 | Loss: 1.058115 | Accuracy: 0.985863
# Epoch: 27 | Batch: 40/69 | Loss: 1.054591 | Accuracy: 0.989844
# Epoch: 27 | Batch: 60/69 | Loss: 1.057742 | Accuracy: 0.982031
# --------------------------------------------------
# End of epoch 27 | time: 0.2748587131500244 | val_loss: 0.021243 | val_acc: 0.796517
# --------------------------------------------------
# EarlyStopping counter: 10 out of 10
# Early Stopping!

# %% [markdown]
# Validation plot

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([loss.cpu() for loss in loss_log])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %%
plt.plot(accuracy_log)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# # Prediction

# %%
best_checkpoint = TREC_classification_Model(vocab_size, embedding_size, num_class).to(device)

# %%
best_checkpoint.load_state_dict(torch.load("checkpoint.pt"))
# Out:
# <All keys matched successfully>

# %%
def predict(text):
    with torch.no_grad():
        text = torch.tensor(vocabulary(tokenizer(text))).to(device)
        output = best_checkpoint(text, torch.tensor([0]).to(device))
        
        return output.argmax(1).item()

# %%
predicted = []
for text in test_data:
    predicted.append(predict(text))

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %%
print(f"Accuracy: {accuracy_score(test_labels, predicted):.6f} | Precision: {precision_score(test_labels, predicted, average = 'macro'):.6f} | Recall: {recall_score(test_labels, predicted, average = 'macro'):.6f} | F1 score: {f1_score(test_labels, predicted, average = 'macro'):.6f}")
# Out:
# Accuracy: 0.828000 | Precision: 0.863599 | Recall: 0.788308 | F1 score: 0.813223

# %%
print(classification_report(test_labels, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91        65
#            1       0.74      0.81      0.78        81
#            2       0.96      0.84      0.90       113
#            3       0.68      0.81      0.74        94
#            4       1.00      0.56      0.71         9
#            5       0.85      0.83      0.84       138
#
#     accuracy                           0.83       500
#    macro avg       0.86      0.79      0.81       500
# weighted avg       0.84      0.83      0.83       500

# %%
print(confusion_matrix(test_labels, predicted))
# Out:
# [[ 57   1   1   5   0   1]
#  [  0  66   2   6   0   7]
#  [  0   5  95   7   0   6]
#  [  3  12   0  76   0   3]
#  [  0   1   0   0   5   3]
#  [  0   4   1  18   0 115]]

# %%
import seaborn as sns

# %%
sns.heatmap(confusion_matrix(test_labels, predicted), annot = True, fmt = "g")
plt.ylabel("Predicted")
plt.xlabel("Ground truth")
plt.show()
